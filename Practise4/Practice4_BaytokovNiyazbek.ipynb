# %% [markdown]
# #Практическая работа №4
# ##Тема: «Линейная регрессия»
# ##Выполнил студент: Байтоков Ниязбек
# ##ВАРИАНТ: Pokemon.csv, https://raw.githubusercontent.com/NiyazBD/SystemAI_Baytokov/main/Practice2/Pokemon.csv

# %% [markdown]
# ###Задание 1. Загрузить данные из dataset "Титаник"

# %%
from sklearn.metrics import classification_report, confusion_matrix

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import seaborn as sns

import warnings

url = "https://raw.githubusercontent.com/SpirinIgor/System-AI/main/Practice2/Datasets/titanic_train.csv"
mainDf = pd.read_csv(url)

# %% [markdown]
# ###Задание 2. Произвести предобработку данных dataset "Титаник" и сохранить результаты каждый в отдельный датафрейм

# %% [markdown]
# ####1.Удалить все пуcтые значения и сохранить результаты в датафрейм df_del

# %%
df_del = mainDf.dropna()

# %% [markdown]
# ####2.Замена на конкретное значение все пуcтые и сохранить результаты в датафрейм df_num

# %%
df_num = mainDf.fillna(123456789)

# %% [markdown]
# ####3.Заменить все пуcтые значения на среднее значение и сохранить результаты в датафрейм df_means

# %%
mainDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_means = mainDf.fillna(mainDf.Age.mean())
df_means
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ####4.Заменить все путые заначения на медеанные значение и сохранить результаты в датафрейм df_medians

# %%
df_medians = mainDf.fillna(mainDf.Age.median())
df_medians
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ####5.Замена на предыдущее или следующее значение и сохранить результаты в датафрейм df_fb_fill

# %%
df_fb_fill = mainDf.fillna(method="ffill")
df_fb_fill
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ###Задание 3. Приметить к каждому датафрейму алгоритм линейной регресси

# %% [markdown]
# ####df_del Пример Сани

# %%
# Модель df_del
# Игнорировать все предупреждения
warnings.filterwarnings('ignore')

# Фильтрация данных возраста
df_del_25 = df_del[df_del['Age'] == 25]

# Подготовка данных: выбор признаков и целевой переменной
X1 = df_del_25[['Pclass', 'Sex', 'Embarked', 'Fare']]
y1 = df_del_25['Survived']

# Преобразование категориальных переменных в числовые
X1['Sex'] = X1['Sex'].map({'male': 0, 'female': 1})
X1['Embarked'] = X1['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

# Стандартизация признаков
scaler = StandardScaler()
X1_scaled = scaler.fit_transform(X1)

# Разделение данных на обучающую и тестовую выборки
X1_train, X1_test, y1_train, y1_test = train_test_split(X1_scaled, y1, test_size=0.2, random_state=42)

# Построение и обучение модели
model1 = LogisticRegression()
model1.fit(X1_train, y1_train)

# Предсказание на тестовых данных
y1_pred = model1.predict(X1_test)

# %% [markdown]
# пример Спирина

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np

from sklearn.metrics import accuracy_score, recall_score, f1_score

import warnings
# Игнорировать все предупреждения
warnings.filterwarnings('ignore')

# Пример данных
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]]) # Независимые переменные
y = np.dot(X, np.array([1, 2])) + 3 # Зависимая переменная

# Разделение данных на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Создание и обучение модели линейной регрессии
model = LinearRegression()
model.fit(X_train, y_train)

# Прогнозирование на тестовых данных
y_pred = model.predict(X_test)

# Вывод коэффициентов модели
print("Коэффициенты модели:", model.coef_)
print("Свободный член модели:", model.intercept_)

# Оценка модели
accuracy = accuracy_score(np.round(y_test), np.round(y_pred))
recall = recall_score(np.round(y_test), np.round(y_pred))
f1 = f1_score(np.round(y_test), np.round(y_pred))

print(f"Accuracy: {accuracy}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Коэффициенты модели: [1. 2.]
# Свободный член модели: 3.0
# Accuracy: 1.0
# Recall: 0.0
# F1 Score: 0.0

# %% [markdown]
# df_del linear regression

# %%
# Игнорировать все предупреждения
warnings.filterwarnings('ignore')

# Пример данных
X = df_del[['Survived']] # Независимые переменные
y = df_del[['Pclass']] # Зависимая переменная

# Разделение данных на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Создание и обучение модели линейной регрессии
model = LinearRegression()
model.fit(X_train, y_train)

# Прогнозирование на тестовых данных
y_pred = model.predict(X_test)

# Вывод коэффициентов модели
print("Коэффициенты модели:", model.coef_)
print("Свободный член модели:", model.intercept_)

# Оценка модели
accuracy = accuracy_score(np.round(y_test), np.round(y_pred))
recall = recall_score(np.round(y_test), np.round(y_pred))
f1 = f1_score(np.round(y_test), np.round(y_pred))

print(f"Accuracy: {accuracy}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Коэффициенты модели: [[-0.07324001]]
# Свободный член модели: [1.24528302]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-931590835a14> in <cell line: 24>()
#      22 # Оценка модели
#      23 accuracy = accuracy_score(np.round(y_test), np.round(y_pred))
# ---> 24 recall = recall_score(np.round(y_test), np.round(y_pred))
#      25 f1 = f1_score(np.round(y_test), np.round(y_pred))
#      26
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2096     array([1. , 1. , 0.5])
#    2097     """
# -> 2098     _, r, _, _ = precision_recall_fscore_support(
#    2099         y_true,
#    2100         y_pred,
#
# ...
