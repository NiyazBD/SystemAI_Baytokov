# %% [markdown]
# #Практическая работа №2
#
# ##Тема: «Предобработка данных в Pandas»
#
# ##Выполнил студент: Байтоков Ниязбек
# ##Вариант: 2

# %%
import pandas as pd

# %% [markdown]
# ###Задание 1. Создать Series s1 и s2 по картинке

# %%
df1 = pd.DataFrame({'apples': [3,2,0,1]})
df1
# Out:
#    apples
# 0       3
# 1       2
# 2       0
# 3       1

# %%
df2 = pd.DataFrame({'oranges': [0,3,7,2]})
df2
# Out:
#    oranges
# 0        0
# 1        3
# 2        7
# 3        2

# %% [markdown]
# ###Задание 2. Создать DataFrame df1 по картинке

# %%
df3 = pd.DataFrame({'apples': [3,2,0,1],'oranges': [0,3,7,2]})
df3
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# ###Задание 3. Загрузить ваш DataSet

# %%
url = 'https://raw.githubusercontent.com/NiyazBD/SystemAI_Baytokov/main/Practice2/Pokemon.csv'
pokemon = pd.read_csv(url)

# %% [markdown]
# ###Задание 4. Показать первые 10 записей вашего DataFrame

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# ###Задание 5. Показать последние 10 записей вашего DataFrame

# %%
pokemon.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# 791       97       80    123           6      False
# 792      131       98     99           6       True
# 793      131       98     99           6       True
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# ###Задание 6. Показать случайные 10 записей вашего DataFrame

# %%
pokemon.sample(10)
# Out:
#        #                       Name  Type 1    Type 2  Total   HP  Attack  \
# 363  332                   Cacturne   Grass      Dark    475   70     115
# 398  363                     Spheal     Ice     Water    290   70      40
# 413  376    MetagrossMega Metagross   Steel   Psychic    700   80     145
# 610  550                   Basculin   Water       NaN    460   70      92
# 696  635                  Hydreigon    Dark    Dragon    600   92     105
# 717  649                   Genesect     Bug     Steel    600   71     120
# 37    32                   Nidoran♂  Poison       NaN    273   46      57
# 707  644                     Zekrom  Dragon  Electric    680  100     150
# 7      6  CharizardMega Charizard X    Fire    Dragon    634   78     130
# 332  306                     Aggron   Steel      Rock    530   70     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 363       60      115       60     55           3      False
# 398       50       55       50     25           3      False
# 413      150      105      110    110           3      False
# 610       65       80       55     98           5      False
# 696       90      125       90     98           5      False
# 717       95      120       95     99           5      False
# 37        40       40       40     50           1      False
# 707      120      120      100     90           5       True
# 7        111      130       85    100           1      False
# 332      180       60       60     50           3      False

# %% [markdown]
# ###Задание 7. Показать типы данных для каждого столбца в DataFrame

# %%
pokemon.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# ###Задание 8. Показать информацию о DataFrame, включая количество непропущенных значений, типы данных

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# ###Задание 9. Показать статистический анализ числовых столбцов, включая среднее, стандартное отклонение, минимум и максимум о DataFrame

# %%
pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# ###Задание 10. Показать Возвращает DataFrame с булевыми значениями, указывающими на пропущенные значения

# %%
pokemon.isna()
# Out:
#          #   Name  Type 1  Type 2  Total     HP  Attack  Defense  Sp. Atk  \
# 0    False  False   False   False  False  False   False    False    False
# 1    False  False   False   False  False  False   False    False    False
# 2    False  False   False   False  False  False   False    False    False
# 3    False  False   False   False  False  False   False    False    False
# 4    False  False   False    True  False  False   False    False    False
# ..     ...    ...     ...     ...    ...    ...     ...      ...      ...
# 795  False  False   False   False  False  False   False    False    False
# 796  False  False   False   False  False  False   False    False    False
# 797  False  False   False   False  False  False   False    False    False
# 798  False  False   False   False  False  False   False    False    False
# 799  False  False   False   False  False  False   False    False    False
#
#      Sp. Def  Speed  Generation  Legendary
# 0      False  False       False      False
# 1      False  False       False      False
# 2      False  False       False      False
# 3      False  False       False      False
# 4      False  False       False      False
# ..       ...    ...         ...        ...
# 795    False  False       False      False
# 796    False  False       False      False
# 797    False  False       False      False
# 798    False  False       False      False
# 799    False  False       False      False
#
# [800 rows x 13 columns]

# %% [markdown]
# ###Задание 11. Заменить пропущенные значения значением value в DataFrame

# %%
pokemon.fillna('Пустое значение')
# Out:
#        #                   Name   Type 1           Type 2  Total  HP  Attack  \
# 0      1              Bulbasaur    Grass           Poison    318  45      49
# 1      2                Ivysaur    Grass           Poison    405  60      62
# 2      3               Venusaur    Grass           Poison    525  80      82
# 3      3  VenusaurMega Venusaur    Grass           Poison    625  80     100
# 4      4             Charmander     Fire  Пустое значение    309  39      52
# ..   ...                    ...      ...              ...    ...  ..     ...
# 795  719                Diancie     Rock            Fairy    600  50     100
# 796  719    DiancieMega Diancie     Rock            Fairy    700  50     160
# 797  720    HoopaHoopa Confined  Psychic            Ghost    600  80     110
# 798  720     HoopaHoopa Unbound  Psychic             Dark    680  80     160
# 799  721              Volcanion     Fire            Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# 1         63       80       80     60           1      False
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 4         43       60       50     65           1      False
# ..       ...      ...      ...    ...         ...        ...
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ###Задание 12. Заменить пропущенные значения значением среднего в DataFrame

# %%
pokemon.fillna(pokemon.mean())
# Out:
# <ipython-input-33-d89272836b82>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pokemon.fillna(pokemon.mean())
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ###Задание 13.  Заменить пропущенные значения значением медианны в DataFrame

# %%
pokemon.fillna(pokemon.median())
# Out:
# <ipython-input-10-058a6111878e>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pokemon.fillna(pokemon.median())
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ###Задание 14.  Заменить пропущенные значения значением максимальным в DataFrame

# %%
pokemon.fillna(pokemon.max())
# Out:
# <ipython-input-11-134593f49afe>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pokemon.fillna(pokemon.max())
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ###Задание 15.  Заменить пропущенные значения значением минимальным в DataFrame

# %%
pokemon.fillna(pokemon.min())
# Out:
# <ipython-input-12-25cb25e23b37>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pokemon.fillna(pokemon.min())
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ###Задание 16. Показать количество уникальных значений в каждом столбце в DataFrame

# %%
pokemon.nunique()
# Out:
# #             721
# Name          800
# Type 1         18
# Type 2         18
# Total         200
# HP             94
# Attack        111
# Defense       103
# Sp. Atk       105
# Sp. Def        92
# Speed         108
# Generation      6
# Legendary       2
# dtype: int64

# %% [markdown]
# ###Задание 17. Подсчитать количество вхождений каждого уникального значения в столбце в DataFrame

# %%
pokemon.value_counts()
# Out:
# #    Name                   Type 1    Type 2    Total  HP   Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1    Bulbasaur              Grass     Poison    318    45   49      49       65       65       45     1           False        1
# 479  RotomFrost Rotom       Electric  Ice       520    50   65      107      105      107      86     4           False        1
# 494  Victini                Psychic   Fire      600    100  100     100      100      100      100    5           True         1
# 492  ShayminSky Forme       Grass     Flying    600    100  103     75       120      75       127    4           True         1
# 487  GiratinaOrigin Forme   Ghost     Dragon    680    150  120     100      120      100      90     4           True         1
#                                                                                                                               ..
# 257  Blaziken               Fire      Fighting  530    80   120     70       110      70       80     3           False        1
# 256  Combusken              Fire      Fighting  405    60   85      60       85       60       55     3           False        1
# 254  SceptileMega Sceptile  Grass     Dragon    630    70   110     75       145      85       145    3           False        1
# 251  Celebi                 Psychic   Grass     600    100  100     100      100      100      100    2           False        1
# 721  Volcanion              Fire      Water     600    80   110     120      130      90       70     6           True         1
# Length: 414, dtype: int64

# %% [markdown]
# ###Задание 18. Удалить строки с пропущенными значениями в DataFrame

# %%
pokemon.dropna()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 6        109       85    100           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [414 rows x 13 columns]

# %% [markdown]
# ### Задание 19. Показать булевы значения, указывающие на дубликаты строк в DataFrame

# %%
pokemon.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %% [markdown]
# ### Задание 20. Удалить дубликаты строк из DataFrame

# %%
pokemon.drop_duplicates()
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ### Задание 21. Заменить определенное значения в DataFrame на указанные значения

# %%
pokemon.replace('Poison','ЯД!!!!!!!!!!')
# Out:
#        #                   Name   Type 1        Type 2  Total  HP  Attack  \
# 0      1              Bulbasaur    Grass  ЯД!!!!!!!!!!    318  45      49
# 1      2                Ivysaur    Grass  ЯД!!!!!!!!!!    405  60      62
# 2      3               Venusaur    Grass  ЯД!!!!!!!!!!    525  80      82
# 3      3  VenusaurMega Venusaur    Grass  ЯД!!!!!!!!!!    625  80     100
# 4      4             Charmander     Fire           NaN    309  39      52
# ..   ...                    ...      ...           ...    ...  ..     ...
# 795  719                Diancie     Rock         Fairy    600  50     100
# 796  719    DiancieMega Diancie     Rock         Fairy    700  50     160
# 797  720    HoopaHoopa Confined  Psychic         Ghost    600  80     110
# 798  720     HoopaHoopa Unbound  Psychic          Dark    680  80     160
# 799  721              Volcanion     Fire         Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# 1         63       80       80     60           1      False
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 4         43       60       50     65           1      False
# ..       ...      ...      ...    ...         ...        ...
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# ### Задание 22. Сохранить DataFrame в формат Excel с именем Practice2_dataset.xlsx

# %%
pokemon.to_excel('Practice2_dataset.xlsx')

# %% [markdown]
# ###Задание 23. Сохранить DataFrame в формат CSV с именем Practice2_ dataset.CSV

# %%
pokemon.to_csv('Practice2_dataset.csv')

# %% [markdown]
# ###Задание 24. Сохранить DataFrame в формат JSON с именем Practice2_ dataset.json

# %%
pokemon.to_json('Practice2_dataset.json')
